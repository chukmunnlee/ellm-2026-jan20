# %% [markdown]
# # Runtime Setup
#
# This notebook will setup the Python runtime that you will be using for the duration of the course.
#
# After connecting to the runtime, execute the next cell to install all required libraries.

# %%
# 1. Install uv
# !curl -LsSf https://astral.sh/uv/install.sh | sh

import os
os.environ['PATH'] = f"{os.environ['HOME']}/.local/bin:{os.environ['PATH']}"

# 2. Initialize a project (if one doesn't exist)
# This creates the pyproject.toml
# !uv init --no-workspace

# 3. Use 'uv add' to manage your dependencies
# This updates your pyproject.toml and creates a uv.lock

# !uv add chromadb pypandoc pipeline
# !uv add transformers datasets evaluate rouge_score loralib peft
# !uv add ipykernel ipywidgets
# !uv add langchain-community sentence-transformers unstructured
# !uv add diffusers accelerate scipy safetensors
# !uv add torch torchdata torchvision
# !uv add smolagents openai
# !uv add nbconvert[webpdf]
# !uv add huggingface_hub[hf_xet]
# !uv add unstructured
# !uv add pandas numpy networkx openpyxl
# !uv add python-magic python-pptx
# !uv add docx2txt docx msoffcrypto-tool
# !uv add jq nltk
# !uv add duckduckgo_search ddgs
# !uv add pypdf pymupdf Pillow
# !uv add "protobuf<5.0.0"

#
# 4. CRITICAL STEP: Sync the project to the SYSTEM environment
# This makes the packages visible to your Colab Notebook
# !uv pip install --system -r pyproject.toml
